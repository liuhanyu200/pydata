# %% [markdown]
# ### 《python数据可视化之matplotlib实践》学习笔记

# %% [markdown]
# #### 第一章

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.05, 10, 1000)
y = np.cos(x)
plt.plot(x, y, ls="-", lw=2, label="plot figure")
plt.legend() # 增加图例
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.05,10,1000)
y = np.random.rand(1000)
plt.scatter(x,y,c='black',label="scatter figure")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.05, 10, 1000)
y = np.sin(x)
plt.plot(x, y, ls="-.", lw=2, c="c", label="plot figure")
plt.legend() # 增加图例
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
